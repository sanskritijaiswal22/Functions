# %% [markdown]
# # **Functions Assignments questions**
#
#
# #Theory questins
#
# 1. What is the difference between a function and a method in Python?
# -
# **Function* : A function is a block of reusable code defined using the def keyword and is not bound to any object.
# Example:

# %%
def greet():
    print("Hello")

# %% [markdown]
# **Method**: A method is like a function but is associated with an object (especially in classes).
# Example:

# %%
name = "Sanskriti"
print(name.upper())  # upper() is a method
# Out:
# SANSKRITI

# %% [markdown]
# 2. Explain the concept of function arguments and parameters in Python.
# -
# Parameter : The variable listed inside the parentheses in the function definition.
#
# **Argument**: The actual value passed when calling the function.
# Example:

# %%
def add(a, b):  # a, b are parameters
    return a + b

add(2, 3)  # 2 and 3 are arguments
# Out:
# 5

# %% [markdown]
# 3. What are the different ways to define and call a function in Python?
# -
#  Using def:

# %%
def greet():
    print("Hello")
greet()
# Out:
# Hello

# %% [markdown]
# Using lambda:

# %%
square = lambda x: x*x
print(square(4))
# Out:
# 16

# %% [markdown]
# 4. What is the purpose of the `return` statement in a Python function?
# -
#  The return statement is used to send the result from a function to the caller.
# Example:

# %%
def square(x):
    return x * x
print(square(5))
# Out:
# 25

# %% [markdown]
# 5. What are iterators in Python and how do they differ from iterables?
# -
#   **Iterable**: Any object that can return an iterator (like lists, strings).
#
#   **Iterator**: An object with __next__() method used to fetch elements one at a time.
# Example:

# %%
lst = [1, 2, 3]
it = iter(lst)  # creates iterator
print(next(it))
# Out:
# 1

# %% [markdown]
# 6. Explain the concept of generators in Python and how they are defined
# -
#  Generators are functions that yield values one at a time using the yield keyword instead of return.
# Example:

# %%
def gen_nums():
    yield 1
    yield 2

# %% [markdown]
# 7. What are the advantages of using generators over regular functions?
# -  Memory efficient (do not store all values at once)
# Used for large datasets or streams
#  8. What is a lambda function in Python and when is it typically used?
#  -
#  A small anonymous function using lambda keyword.
# Syntax: lambda arguments: expression
# Example:

# %%
add = lambda a, b: a + b

# %% [markdown]
# 9. Explain the purpose and usage of the `map()` function in Python
# -
# Used to apply a function to all items in an iterable.
# Example:

# %%
nums = [1, 2, 3]
squares = list(map(lambda x: x*x, nums))

# %% [markdown]
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
# -
# function: map()
#
#  purpose: 	Applies function to all elements
#
#  example :	map(lambda x: x*2, [1,2,3])
#  -
#
#  function: filter()
#
#    purpose: 	Filters elements based on condition
#
#    Example  	filter(lambda x: x>2, [1,2,3])
#
#   function: reduce()
#
#   purpose: Performs rolling computation
#
#   Example: reduce(lambda x,y: x+y, [1,2,3])

# %% [markdown]
# 11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];
# -
#  ![assignmt.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #practical questions

# %% [markdown]
# 1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
# the list.

# %%
def sum_even_numbers(numbers):
    total = 0
    for num in numbers:
        if num % 2 == 0:
            total += num
    return total

# %% [markdown]
# 2. Create a Python function that accepts a string and returns the reverse of that string.

# %%
def reverse_string(s):
    return s[::-1]

# %% [markdown]
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of
# each number

# %%
def square_list(numbers):
    return [num ** 2 for num in numbers]

# %% [markdown]
# 4. Write a Python function that checks if a given number is prime or not from 1 to 200

# %%
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

# Example usage:
# for i in range(1, 201):
#     if is_prime(i):
#         print(i, "is prime")

# %% [markdown]
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
# terms.

# %%
class Fibonacci:
    def __init__(self, terms):
        self.terms = terms
        self.a, self.b = 0, 1
        self.count = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.terms:
            raise StopIteration
        value = self.a
        self.a, self.b = self.b, self.a + self.b
        self.count += 1
        return value

# %% [markdown]
# 6. Write a generator function in Python that yields the powers of 2 up to a given exponent

# %%
def powers_of_two(n):
    for i in range(n + 1):
        yield 2 ** i

# %% [markdown]
# 7. Implement a generator function that reads a file line by line and yields each line as a string.

# %%
def read_file_line_by_line(filename):
    with open(filename, 'r') as file:
        for line in file:
            yield line.strip()

# %% [markdown]
# 8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple

# %%
tuples = [(1, 3), (4, 1), (2, 2)]
sorted_list = sorted(tuples, key=lambda x: x[1])
# Output: [(4, 1), (2, 2), (1, 3)]

# %% [markdown]
# 9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

# %%
celsius = [0, 20, 37, 100]
fahrenheit = list(map(lambda c: (c * 9/5) + 32, celsius))

# %% [markdown]
# 10. Create a Python program that uses `filter()` to remove all the vowels from a given string.

# %%
def remove_vowels(s):
    vowels = 'aeiouAEIOU'
    return ''.join(filter(lambda x: x not in vowels, s))

# %% [markdown]
# 11) Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:
# ![asn.jpg](data:image/jpeg;base64,...)

# %%
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]

result = list(map(
    lambda x: (x[0], x[2] * x[3] + (10 if x[2] * x[3] < 100 else 0)),
    orders
))

print(result)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
